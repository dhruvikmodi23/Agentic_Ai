# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
response = llm.invoke("How many moons does Jupiter have?")
print(response.text)
# Out:
# Jupiter currently has **95 confirmed moons**.
#
# This number can change as new moons are discovered and officially recognized. Among its many moons are the four large Galilean moons (Io, Europa, Ganymede, and Callisto), which are easily visible with a small telescope.
#
# While Jupiter used to hold the record, Saturn now has the most known moons in our solar system.

# %%
response = llm.invoke([
    ["system", "You are a helpful assistant that answers in short one line"],
    ["human", "How many moons does Jupiter have?"]
])
print(response.text)
# Out:
# Jupiter has 95 confirmed moons.

# %%
prompt = "Write a single tagline for a quirky coffee shop. Only output the tagline, nothing else."

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

response = llm.invoke(prompt)
print(response.text)
# Out:
# Where coffee gets curious.

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1)

response = llm.invoke(prompt)
print(response.text)
# Out:
# Sip outside the lines.

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="qwen/qwen3-32b", reasoning_format="parsed")

messages = [
    (
        "system",
        "You are a helpful assistant that gives a short answer to a question",
    ),
    (
        "human", 
        "How many moons does Jupiter have?"
    ),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# As of the latest data, Jupiter has **95 confirmed moons**. This number includes both the well-known Galilean moons and numerous smaller, more recently discovered ones. The count can change as new discoveries are made.
